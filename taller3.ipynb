# %% [markdown]
# ## Taller 3
#
# ## Miguel Fabris Avila
# ## cc: 1063719267
# ## miguel.fabris@upb.edu.co
# ## ID: 502243
#
# ## Alvaro Jose Zamora cury
# ## cc: 1003064557
# ## alvaro.zamora@upb.edu.co
# ## ID: 502225

# %%
import os


salas= { 1: {'id':1,'capacidad': 5, 'valor_hora': 50000},  2: {'id':2,'capacidad': 10, 'valor_hora': 80000}, 
        3: {'id':3,'capacidad': 20, 'valor_hora': 150000}}

menu = {1: {'id':1,'nombre': 'hot dog', 'valor': 10000}, 2: {'id':2,'nombre': 'hamburguesa', 'valor': 12000},
       3: {'id':3,'nombre': 'Salchipapas', 'valor': 15000}, 4: {'id':4,'nombre': 'combo palomitas + gaseosa', 'valor': 20000}}

peliculas= ['101 dálmatas' , 'Aladdin','Game Of Thrones', 'Big Hero 6','casa de papel','Palpitos']

# %%
flag = True
while flag:
    print("""Bienvenido a Cinepython, Donde puedes elegir tu pelicula o serie y disfrutar de la mejor comida. EMPECEMOS...
     
    1. Alquiler
    2. Menu
    0. Salir
    """)
    choice = input("Seleccione una opción:\n")
    if choice == '0':
        print("Gracias por elegir a Cinepython!!!")
        break
    elif choice == '1':
           # nostramos el menu de de las salas 
            for i in range(1, len(salas)+1):
                 print(i,'Sala ',i,':','capacidad',salas[i]['capacidad'],'personas  costo por horas',salas[i]['valor_hora'])
            peliculaselec=''   
            lines =len(salas)+1
            line = 1
            op=int(input('Ingrese una opcion valida \n'))
            while line < lines:
                if op==salas[line]['id']: 
                    print('Cantidad de horas que desea ver? \n')
                    valorHora=int(input())
                    titulo='Detalles de su eleccion'
                    capacidad=salas[op]['capacidad'],
                    valorhoras=int(salas[op]['valor_hora'])
                    totalpagosala= (valorHora) * (valorhoras)
                    break
                elif op<1 or op>=lines:
                    
                    op=int(input('Oh!!! Recuerde ingresar una opcion valida \n'))
                         
                else:
                    line += 1  
      
                    
            print('------------Elija la Pelicula o Serie que desea ver---------------\n')
            for i in range(len(peliculas)):
                 print(i,'.',peliculas[i])
            
            # se pide la pelicula
            
            lines =len(peliculas)
            line = 0
            op=int(input('Digite una opcion para elegir su Pelicula o Serie \n'))
            while line < lines:
                if op==line: 
                    peliculaselec=peliculas[line]
                   
                    break
                elif op<0 or op>=lines:
                    
                     op=int(input('Oh!!! Recuerde ingresar una opcion valida \n'))
                         
                else:
                    line += 1  
            
            
          
        
        
    elif choice == '2':
            submenu=True
            while submenu:
                print("""Aquí podras pedir las comidas disponibles de Cinepython. Elija opcion 1 para ir al menu; 0 para ir atras.
     
                      1. Menu CinePython
                      0. Ir atras
                      """)
                menuop = input("Ejila una opcion...\n")
                if menuop  == '0':
                    break
                elif  menuop=='1':
                
                       for i in range(1, len(menu)+1):
                             print(i,'.',menu[i]['nombre'],'costo :',menu[i]['valor'])
                
                       lines = len(menu)+1
                       line = 1
                       op=int(input('ingrese una opcion valida \n'))
                       while line < lines:
                            if op==menu[line]['id']: 
                                print('Ingrese la cantidad comidas \n')
                                cantidad=int(input())
                                nombre=menu[op]['nombre'],
                                valorcomida=int(menu[op]['valor'])
                                totalpagomenu= (cantidad) * (valorcomida)
                                break
                            elif op<1 or op>=lines:
                    
                                 op=int(input('Oh!!! Recuerde ingresar una opcion valida \n'))
                         
                            else:
                                line += 1  
          
                
                else:
                    print("\nComando ingresado no reconocido. Por favor, ingresa una opción válida.\n")
                    
         
         
       
    else:
        print("\nComando ingresado no reconocido. Por favor, ingresa una opción válida.\n")
valortotalpagar=totalpagomenu+totalpagosala
        
print('------FACTURA CINYPYTHON---------',
      '\n total a pagar de la sala \n\n Capacidad : ',
      capacidad,' Personas\n costo por hora :', valorhoras,
      ' Pesos \n numero de horas: ',valorHora,'\n pago unitario :', 
      totalpagosala,'Pesos \n Comida: ', 
      nombre,'\n Precio :',valorcomida,'Pesos \n cantidad: ',cantidad,
      'Peso \n  valor unitario: ',totalpagomenu,'Pesos \n Total a pagar: ',valortotalpagar,' Pesos')
print('Pelicula o Serie seleccionada :',peliculaselec)


file = open("C:/Users/SoporteTI/Documents/ingesta de datos/factura.txt", "w")
file.write(" "+ os.linesep)
file.close()
# Out:
# Bienvenido a Cinepython, Donde puedes elegir tu pelicula o serie y disfrutar de la mejor comida. EMPECEMOS...
#
#     1. Alquiler
#     2. Menu
#     0. Salir
#
# Seleccione una opción:
# 1
# 1 Sala  1 : capacidad 5 personas  costo por horas 50000
# 2 Sala  2 : capacidad 10 personas  costo por horas 80000
# 3 Sala  3 : capacidad 20 personas  costo por horas 150000
# Ingrese una opcion valida
# 1
# Cantidad de horas que desea ver?
#
# 1
# ------------Elija la Pelicula o Serie que desea ver---------------
#
# 0 . 101 dálmatas
# 1 . Aladdin
# 2 . Game Of Thrones
# 3 . Big Hero 6
# 4 . casa de papel
# 5 . Palpitos
# Digite una opcion para elegir su Pelicula o Serie
# 2
# Bienvenido a Cinepython, Donde puedes elegir tu pelicula o serie y disfrutar de la mejor comida. EMPECEMOS...
#
#     1. Alquiler
#     2. Menu
#     0. Salir
#
# Seleccione una opción:
# 2
# Aquí podras pedir las comidas disponibles de Cinepython. Elija opcion 1 para ir al menu; 0 para ir atras.
#
# ...

# %%
4*5
